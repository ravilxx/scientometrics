# %%
# https://github.com/ravilxx/scientometrics

# %%
#%matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
####### reading csv
sc_df = pd.read_csv('DeepLearning_v.1.0.csv', encoding='latin1')
keys=np.array(sc_df.keys())
ka=np.array(keys.shape)
labels=np.array(sc_df['Field'])
#end reading csv

# %% [markdown]
# ### make regression

# %%
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error, r2_score

count=0         #number of row
dotPerYear=5    #dots per year after regression
print_curves=1  #Yes
degree=7        #regression dergree 
predictYears=2  #Years of predictions
def regCurves(count,dotPerYear,sc_df,degree,predictYears,print_curves):
    keys=np.array(sc_df.keys())
    ka=np.array(keys.shape)
    labels=np.array(sc_df['Field'])
    scnum=sc_df.loc[count,keys[1:ka[0]-1]]
    #print(scnum)
    y=np.array(scnum)
    #x=np.arange(ka[0]-2)
    x=keys[1:ka[0]-1]
    x = [int(i) for i in x]  #convert to integer
    x=np.array(x)
    x=x-2000
    X=x[:,np.newaxis]
   #x2=np.linspace(x[0],x[-1]+1,((x[-1]+1)-x[0])*dotPerYear) #+predictYears*dotPerYear)
   #+predictYears*dotPerYear
    x2=np.linspace(x[0],x[-1]+1+predictYears,((x[-1]+1)-x[0])*dotPerYear)
    X2=x2[:,np.newaxis]
    degree=7
    poly=make_pipeline(PolynomialFeatures(degree),Ridge())
    poly.fit(X,y)
    y_pred=poly.predict(X)

    y_pred2=poly.predict(X2)

    print(labels[count])
    print('Degree= %.2f' % degree)
    print('Mean squared error: %.2f' % mean_squared_error(y,y_pred))
    print('variance error: %.2f' % r2_score(y,y_pred))
    #print('variance error: %.2f' % r2_score(y,y_pred))
    mse=mean_squared_error(y,y_pred)
    r2=r2_score(y,y_pred)
    ##print('MSE, r2 : %.2f, %.2f' % mse % r2 %r2)
    #print('MSE:=', mse, 'r2=', r2)
    ##label='MSE:='+ mse+'r2='+ r2

        #plt.plot(X_train,y_pred,color='silver', linewidth=2, label='degree=%d' % degree)
    #plt.scatter(X_train,y_pred,color=colors[count], s=10, marker='o', label='degree=%d' % degree)
    #plt.scatter(X2,y_pred2,s=10, marker='o', color='red', label='degree=%d' % degree )    #how to print multi argumentla string?
    if print_curves==1:
        plt.scatter(X2,y_pred2,s=10, marker='o', label='degree=%d' % degree )    #how to print multi argumentla string?
        plt.plot(X,y_pred,label= labels[count]) #, color='cyan')
        plt.plot(X2,y_pred2,label= 'reg '+labels[count]) #, color='grey')
    #plt.plot(x,y, label= labels[count])
        plt.legend(loc='upper left')
    return X2, y_pred2,dotPerYear,labels[count]
    
x, y,dotPerYear,lbl=regCurves(0,dotPerYear,sc_df,degree,predictYears,1)
# Out:
# Deep Learning + seq2seq (seq2seq, seqtoseq, sequence to sequence, sequence-to-sequence)
# Degree= 7.00
# Mean squared error: 0.30
# variance error: 1.00
# C:\Anaconda3\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.8900325935104905e-18 / 1.1102230246251565e-16
#   RuntimeWarning)

# %%
#calculate of derivatives
def deriv(a,b):
    return((b-a)/2)
def calcDeriv2(y,x, dotPerYear,lbl):
    de=np.zeros(np.array(y.shape))
    num=np.arange(np.array(y.size)-2)
    for i in num:
        de[i+1]=deriv(y[i],y[i+2])
        
    de=de[0:np.array(de.shape)[0]-1]
    x_axis=(x[0:np.array(x.shape)[0]-1])
   
    return de,x_axis

# %% [markdown]
# ### plotting D1

# %%
#####reading csv
# %matplotlib notebook
#%matplotlib inline


####### read csv
#sc_df = pd.read_csv('DeepLearning_v.1.0.csv', encoding='latin1')
#keys=np.array(sc_df.keys())
#ka=np.array(keys.shape)
#labels=np.array(sc_df['Field'])
####### end reading csv

#count=0       #number of row
#dotPerYear=5  #dots per year after regression
#print_curves=1  #Yes
#degree=7       #regression dergree 
#predictYears=3 #Years of predictions

plt.ion()

fig, ax = plt.subplots()
fig.set_size_inches(11,7)
fig.suptitle('D1 (Speed)', fontsize=12)
ax.set_xlabel('Years', fontsize='medium' ) #fontsize=10)
ax.set_ylabel('D1', fontsize='medium')   # relative to plt.rcParams['font.size']
predictYears=2
for i in np.arange(labels.size):
    #plt.figure(1)
    x,y,dotPerYear,lbl=regCurves(i,dotPerYear,sc_df,degree,predictYears,0) 
   
    de,x_axis=calcDeriv2(y,x, dotPerYear,'****')
   
    #ax.plot(x_axis,de)
    ax.plot(x_axis,de,'o',label=lbl)

#print black zero line
zero_line=np.zeros(x_axis.size)
ax.plot(x_axis,zero_line,'-k')
#end print zero line
    
plt.draw()
    
 
plt.legend(loc='upper left')
# Out:
# <img src="data:image/png;base64,..." width="1098.8889179995037">
# Deep Learning + seq2seq (seq2seq, seqtoseq, sequence to sequence, sequence-to-sequence)
# Degree= 7.00
# Mean squared error: 0.30
# variance error: 1.00
# Deep Learning + convolutional (Convolutional, Convolutional Neural Networks, CNN?, ConvNet)
# Degree= 7.00
# Mean squared error: 102.71
# variance error: 1.00
# Deep learning + generative model (generative adversarial network, GAN)
# Degree= 7.00
# Mean squared error: 6.72
# variance error: 1.00
# Deep learning + reinforcement (Reinforcement, RL)
# Degree= 7.00
# Mean squared error: 0.22
# variance error: 0.83
# C:\Anaconda3\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.8900325935104905e-18 / 1.1102230246251565e-16
#   RuntimeWarning)
# ...

# %% [markdown]
# ### plotting D2

# %%
#####reading csv
# %matplotlib notebook
#%matplotlib inline


plt.ion()

fig, ax = plt.subplots()
fig.set_size_inches(11,7)
fig.suptitle('D2 (Acceleration)', fontsize=12)
ax.set_xlabel('Years', fontsize='medium' ) #fontsize=10)
ax.set_ylabel('D2', fontsize='medium')   # relative to plt.rcParams['font.size']
predictYears=2
for i in np.arange(labels.size):
    #plt.figure(1)
    x,y,dotPerYear,lbl=regCurves(i,dotPerYear,sc_df,5,predictYears,0) 
   
    de,x_axis=calcDeriv2(y,x, dotPerYear,'****')
    de,x_axis=calcDeriv2(de,x_axis, dotPerYear,'****')
   
    #ax.plot(x_axis,de)
    ax.plot(x_axis,de,'o',label=lbl)

#print zero line
zero_line=np.zeros(x_axis.size)
ax.plot(x_axis,zero_line,'-k')
#end print zero line
    
plt.draw()
    
 
plt.legend(loc='upper left')
# Out:
# <img src="data:image/png;base64,..." width="1098.8889179995037">
# Deep Learning + seq2seq (seq2seq, seqtoseq, sequence to sequence, sequence-to-sequence)
# Degree= 7.00
# Mean squared error: 0.30
# variance error: 1.00
# Deep Learning + convolutional (Convolutional, Convolutional Neural Networks, CNN?, ConvNet)
# Degree= 7.00
# Mean squared error: 102.71
# variance error: 1.00
# Deep learning + generative model (generative adversarial network, GAN)
# Degree= 7.00
# Mean squared error: 6.72
# variance error: 1.00
# Deep learning + reinforcement (Reinforcement, RL)
# Degree= 7.00
# Mean squared error: 0.22
# variance error: 0.83
# C:\Anaconda3\lib\site-packages\scipy\linalg\basic.py:40: RuntimeWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number/precision: 3.8900325935104905e-18 / 1.1102230246251565e-16
#   RuntimeWarning)
# ...
